# %%
import pandas as pd
import numpy as np
import tensorflow as tf

from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

import cv2
import os

# %%
data_dir = "archive\cats\Data"

# %%
training_data = []

# %%
for image in os.listdir(data_dir):
    image_path = os.path.join(data_dir, image)
    img = cv2.imread(image_path)
    training_data.append(img)

# %%
plt.imshow(cv2.cvtColor(training_data[0], cv2.COLOR_BGR2RGB))
plt.show()

# %%
tf.data.Dataset.list_files(data_dir + "\*.png")
# Out:
# <_ShuffleDataset element_spec=TensorSpec(shape=(), dtype=tf.string, name=None)>

# %% [markdown]
# # Links
#
# https://datascience.stackexchange.com/questions/81313/how-to-use-a-dataset-with-only-one-category-of-data
#
# https://www.youtube.com/watch?v=jztwpsIzEGc&ab_channel=NicholasRenotte
#
# https://machinelearningmastery.com/a-gentle-introduction-to-tensorflow-data-api/
#
# https://www.tensorflow.org/api_docs/python/tf/data/Dataset
